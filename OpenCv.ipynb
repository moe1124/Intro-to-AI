# %% [markdown]
# <a href="https://colab.research.google.com/github/moe1124/Intro-to-AI/blob/main/OpenCv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import opencv
import cv2
from google.colab.patches import cv2_imshow

# %%
#Bring image into notebook
img = cv2.imread('bunny.jpg')
cv2_imshow(img)

#convert to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)

#show gray blurred image
cv2_imshow(img_blur)

#Sobel edge detenction
sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5)

#Plot Sobel edge detencion
cv2_imshow(sobelx)
# Out:
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7F1169696C50>
# <PIL.Image.Image image mode=L size=360x360 at 0x7F116962BC40>
# <PIL.Image.Image image mode=L size=360x360 at 0x7F116962BC40>
